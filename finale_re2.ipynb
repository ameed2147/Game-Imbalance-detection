# %%
import json

# %%
import pandas as pd
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c3391d3b-678d-4650-919a-94824cbd5c10" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c3391d3b-678d-4650-919a-94824cbd5c10">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('dataset1.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 44 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   players                  1000 non-null   object
#  1   radiant_win              1000 non-null   bool
#  2   duration                 1000 non-null   int64
#  3   pre_game_duration        1000 non-null   int64
#  4   start_time               1000 non-null   int64
#  5   match_id                 1000 non-null   int64
#  6   match_seq_num            1000 non-null   int64
#  7   tower_status_radiant     1000 non-null   int64
#  8   tower_status_dire        1000 non-null   int64
#  9   barracks_status_radiant  1000 non-null   int64
#  10  barracks_status_dire     1000 non-null   int64
#  11  cluster                  1000 non-null   int64
#  12  first_blood_time         1000 non-null   int64
#  13  lobby_type               1000 non-null   int64
# ...

# %%
game_modes_to_keep = [22, 23, 4, 1]

# Filter the DataFrame
filtered_df = df[df['game_mode'].isin(game_modes_to_keep)]

# Save the filtered DataFrame to a new CSV file
filtered_df.to_csv('filtered_dataset1.csv', index=False)

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 970 entries, 0 to 999
# Data columns (total 44 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   players                  970 non-null    object
#  1   radiant_win              970 non-null    bool
#  2   duration                 970 non-null    int64
#  3   pre_game_duration        970 non-null    int64
#  4   start_time               970 non-null    int64
#  5   match_id                 970 non-null    int64
#  6   match_seq_num            970 non-null    int64
#  7   tower_status_radiant     970 non-null    int64
#  8   tower_status_dire        970 non-null    int64
#  9   barracks_status_radiant  970 non-null    int64
#  10  barracks_status_dire     970 non-null    int64
#  11  cluster                  970 non-null    int64
#  12  first_blood_time         970 non-null    int64
#  13  lobby_type               970 non-null    int64
# ...

# %%
# Remove columns 23 to 43
filtered_df = filtered_df.drop(filtered_df.columns[21:44], axis=1)

filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 970 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   players                  970 non-null    object
#  1   radiant_win              970 non-null    bool
#  2   duration                 970 non-null    int64
#  3   pre_game_duration        970 non-null    int64
#  4   start_time               970 non-null    int64
#  5   match_id                 970 non-null    int64
#  6   match_seq_num            970 non-null    int64
#  7   tower_status_radiant     970 non-null    int64
#  8   tower_status_dire        970 non-null    int64
#  9   barracks_status_radiant  970 non-null    int64
#  10  barracks_status_dire     970 non-null    int64
#  11  cluster                  970 non-null    int64
#  12  first_blood_time         970 non-null    int64
#  13  lobby_type               970 non-null    int64
# ...

# %%
filtered_df.head()
# Out:
#                                              players  radiant_win  duration  \
# 0  [{'account_id': 83215902, 'player_slot': 0, 't...         True      1852
# 1  [{'account_id': 395961538, 'player_slot': 0, '...        False      1647
# 2  [{'account_id': 344338641, 'player_slot': 0, '...        False      1372
# 3  [{'player_slot': 0, 'team_number': 0, 'team_sl...        False      2839
# 4  [{'account_id': 1089743634, 'player_slot': 0, ...        False      1253
#
#    pre_game_duration  start_time    match_id  match_seq_num  \
# 0                 90  1716497374  7752630629     6528275865
# 1                 60  1716497373  7752630632     6528328830
# 2                 60  1716497363  7752630635     6528238147
# 3                 90  1716497370  7752630636     6528301013
# 4                 60  1716497372  7752630638     6528238637
#
#    tower_status_radiant  tower_status_dire  barracks_status_radiant  ...  \
# ...

# %%
# Convert the DataFrame to an Excel file
filtered_df.to_csv('filtered_dataset1.csv', index=False)
